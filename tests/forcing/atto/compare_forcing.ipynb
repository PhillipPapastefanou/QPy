# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
forc_new = pd.read_csv('/Net/Groups/BSI/work_scratch/ppapastefanou/ATTO_forcing/transient/ATTO_t_1901-2023.dat', sep=r'\s+', skiprows=[1])
forc_old= pd.read_csv('/Net/Groups/BSI/data/quincy/input/point/FLUXNET3/met_forcing/BR-Sa3_t_1901-2003.dat', sep=r'\s+', skiprows=[1])

# %%
forc_old.shape[0]
# Out:
# 1804560

# %%
forc_new.shape[0]/17520
# Out:
# 122.9068493150685

# %%
for i in range(1901, 2023):
    print(forc_new[forc_new['year'] == 1901].shape[0])
# Out:
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472
# 17472

# %%
column = forc_new.columns[1]
# Plot the histogram for df1
#plt.hist(forc_old[column], bins=30, alpha=0.5, label='BR-sa3', color='blue', density=True);

# Plot the histogram for df2 on the same axes
plt.hist(forc_new[column], bins=30, alpha=0.5, label='ATTO', color='red', density=True);
plt.title(column)
# Out:
# Text(0.5, 1.0, 'doy')

# %%
dfm_new = forc_new.groupby("year").mean()
dfm_old = forc_old.groupby("year").mean()
dfm_new = dfm_new[dfm_new.index > 1999]

# %%
plt.plot(dfm_new[column]*365)
#plt.plot(dfm_old[column]*365)
