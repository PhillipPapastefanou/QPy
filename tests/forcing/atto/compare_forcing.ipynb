# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
forc_new = pd.read_csv('/Net/Groups/BSI/work_scratch/ppapastefanou/ATTO_forcing/transient/ATTO_t_1901-2023.dat', sep=r'\s+', skiprows=[1])
forc_old= pd.read_csv('/Net/Groups/BSI/data/quincy/input/point/FLUXNET3/met_forcing/BR-Sa3_t_1901-2003.dat', sep=r'\s+', skiprows=[1])

# %%
forc_new
# Out:
#          year  doy  hour  swvis_srf_down  lw_srf_down    t_air    q_air  \
# 0        1901    1   0.0             0.0     406.2632  297.920  21.1681
# 1        1901    1   0.5             0.0     408.3692  297.770  21.0058
# 2        1901    1   1.0             0.0     412.2975  297.620  20.8448
# 3        1901    1   1.5             0.0     413.7001  297.450  20.6408
# 4        1901    1   2.0             0.0     407.4007  297.230  20.3995
# ...       ...  ...   ...             ...          ...      ...      ...
# 2153323  2023  365  21.5             0.0     410.9527  296.653  18.6275
# 2153324  2023  365  22.0             0.0     410.9527  296.653  18.6275
# 2153325  2023  365  22.5             0.0     410.9527  296.653  18.6275
# 2153326  2023  365  23.0             0.0     410.9527  296.653  18.6275
# 2153327  2023  365  23.5             0.0     410.9527  296.653  18.6275
#
#          press_srf  rain  snow  wind_air  co2_mixing_ratio  co2_dC13  co2DC14  \
# 0         993.0000   0.0   0.0    2.4198             296.8     -6.74     -6.3
# 1         992.0000   0.0   0.0    2.2045             296.8     -6.74     -6.3
# 2         992.0000   0.0   0.0    2.2072             296.8     -6.74     -6.3
# 3         992.0000   0.0   0.0    2.3362             296.8     -6.74     -6.3
# 4         991.0000   0.0   0.0    2.7302             296.8     -6.74     -6.3
# ...            ...   ...   ...       ...               ...       ...      ...
# 2153323   993.5414   0.0   0.0    1.5457             419.3     -8.65    -20.0
# 2153324   993.5414   0.0   0.0    2.2400             419.3     -8.65    -20.0
# 2153325   993.5414   0.0   0.0    1.9653             419.3     -8.65    -20.0
# 2153326   993.5414   0.0   0.0    2.2907             419.3     -8.65    -20.0
# 2153327   993.5414   0.0   0.0    2.1193             419.3     -8.65    -20.0
#
#          nhx_srf_down  noy_srf_down  p_srf_down
# 0              0.1814        0.0989      0.0242
# 1              0.1814        0.0989      0.0242
# 2              0.1814        0.0989      0.0242
# 3              0.1814        0.0989      0.0242
# 4              0.1814        0.0989      0.0242
# ...               ...           ...         ...
# 2153323        0.4274        0.2089      0.0242
# 2153324        0.4274        0.2089      0.0242
# 2153325        0.4274        0.2089      0.0242
# 2153326        0.4274        0.2089      0.0242
# 2153327        0.4274        0.2089      0.0242
#
# [2153328 rows x 17 columns]

# %%
column = forc_new.columns[1]
# Plot the histogram for df1
plt.hist(forc_old[column], bins=30, alpha=0.5, label='BR-sa3', color='blue', density=True);

# Plot the histogram for df2 on the same axes
plt.hist(forc_new[column], bins=30, alpha=0.5, label='ATTO', color='red', density=True);
plt.title(column)
# Out:
# Text(0.5, 1.0, 'doy')

# %%
dfm_new = forc_new.groupby("year").mean()
dfm_old = forc_old.groupby("year").mean()
dfm_new = dfm_new[dfm_new.index > 1999]

# %%
plt.plot(dfm_new[column]*365)
#plt.plot(dfm_old[column]*365)
