# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import sys
from time import perf_counter

sys.path.append("/Net/Groups/BSI/work_scratch/ppapastefanou/src/QPy")

from src.postprocessing.qnc_defintions import Time_Reduction_Type
from src.postprocessing.qnc_output_parser import QNC_output_parser
from src.postprocessing.qnc_ncdf_reader import QNC_ncdf_reader
from src.postprocessing.qnc_rescaler import QNC_Rescaler
from src.postprocessing.qnc_obs_reader import QNC_obs_reader

# %%
os.listdir("/Net/Groups/BSI/scratch/ppapastefanou/simulations/QPy/pheno_hydro")
# Out:
# ['06_std_only',
#  '03_manu_soil_params_phenology',
#  '02_manu_soil_params_phenology',
#  '01_manu_soil_params_phenology',
#  '04_manu_soil_params_phenology',
#  '05_manu_soil_params_phenology',
#  '05_std_only']

# %%
OUTPUT_DIR = '/Net/Groups/BSI/scratch/ppapastefanou/simulations/QPy/kmax_gammastem/10_run_slope_opt_manu_soil_params'
OUTPUT_DIR = '/Net/Groups/BSI/scratch/ppapastefanou/simulations/QPy/pheno_hydro/05_manu_soil_params_phenology'
#OUTPUT_DIR = '/Net/Groups/BSI/scratch/ppapastefanou/simulations/QPy/pheno_hydro/06_std_only'
#OUTPUT_DIR = '/Net/Groups/BSI/scratch/ppapastefanou/simulations/QPy/kmax_gammastem/11_std_only'
post_dir = os.path.join(OUTPUT_DIR, 'post')
rmse_file = os.path.join(post_dir, 'standard_ranking.csv')
parameter_file = os.path.join(OUTPUT_DIR, 'parameters.csv')

# %%
df_parameters = pd.read_csv(parameter_file)
df_parameters
# Out:
#        k_xylem_sat     id    fid  kappa_stem  kappa_leaf  psi50_close  \
# 0          3.37441      0      0    74.82248    0.000742     -1.25137
# 1          3.99423      1      1    61.13250    0.001699     -0.80572
# 2          4.29005      2      2   267.67583    0.000847     -0.66161
# 3          3.83782      3      3   141.36729    0.001802     -1.15719
# 4          2.50427      4      4    95.98165    0.000895     -0.76004
# ...            ...    ...    ...         ...         ...          ...
# 15355      1.87378  15355  15355   171.61673    0.001864     -1.09869
# 15356      1.74007  15356  15356   108.09151    0.001413     -1.43536
# 15357      3.29485  15357  15357   192.00161    0.000632     -1.36137
# 15358      1.89616  15358  15358   153.10465    0.000235     -1.38961
# 15359      3.00562  15359  15359    93.50592    0.001003     -1.06297
#
#        root_dist       saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  \
# 0        6.15626 -5.000000e-07 -11.29774  2.987329e-07       0.51950
# 1        5.97220 -7.000000e-07 -10.75707  2.683873e-08       0.54558
# 2        2.88904 -5.000000e-07  -7.68267  1.202367e-08       0.58051
# 3        5.20739 -9.000000e-07  -8.88948  4.157725e-08       0.55748
# 4        4.23655 -6.000000e-07 -10.40324  1.170916e-08       0.56649
# ...          ...           ...       ...           ...           ...
# 15355    5.30662 -9.000000e-07 -10.26237  1.281924e-07       0.50103
# 15356    2.91354 -8.000000e-07 -10.36249  1.091092e-08       0.51990
# 15357    4.20871 -6.000000e-07 -11.74630  9.047479e-08       0.50045
# 15358    6.28051 -6.000000e-07 -10.06731  1.368678e-08       0.59200
# 15359    6.38426 -8.000000e-07  -8.69257  2.847091e-08       0.56014
#
#        root_scale  slope_leaf_close  gdd_t_air_threshold  gdd_t_air_req  \
# 0       208.37536           6.40282                  9.0          400.0
# 1        65.05572           8.13331                  9.0          400.0
# 2       244.35748           9.62785                  9.0          400.0
# 3       100.78530           9.68269                  9.0          400.0
# 4       115.49635           6.57211                  9.0          400.0
# ...           ...               ...                  ...            ...
# 15355   205.06945           5.45688                  9.0          400.0
# 15356    50.71007           8.54825                  9.0          400.0
# 15357   210.77110           5.70477                  9.0          400.0
# 15358    58.67606           5.71019                  9.0          400.0
# 15359   132.59762           5.82372                  9.0          400.0
#
#         k_gdd
# 0      0.0154
# 1      0.0154
# 2      0.0154
# 3      0.0154
# 4      0.0154
# ...       ...
# 15355  0.0154
# 15356  0.0154
# 15357  0.0154
# 15358  0.0154
# 15359  0.0154
#
# [15360 rows x 16 columns]

# %%
df_rmse = pd.read_csv(rmse_file)
df_rmse= pd.merge(df_parameters, df_rmse, on='fid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_rmse = pd.read_csv(rmse_file)
#       2 df_rmse= pd.merge(df_parameters, df_rmse, on='fid')
#
# File /Net/Groups/BSI/work_scratch/ppapastefanou/envs/phs/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Net/Groups/BSI/work_scratch/ppapastefanou/envs/phs/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Net/Groups/BSI/work_scratch/ppapastefanou/envs/phs/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Net/Groups/BSI/work_scratch/ppapastefanou/envs/phs/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Net/Groups/BSI/work_scratch/ppapastefanou/envs/phs/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Net/Groups/BSI/scratch/ppapastefanou/simulations/QPy/pheno_hydro/05_manu_soil_params_phenology/post/standard_ranking.csv'

# %%
df_rmse
# Out:
#        phi_leaf_min     id    fid  kappa_stem  psi50_close  root_dist  \
# 0          -1.42422      0      0   177.02816     -0.83989    5.69387
# 1          -2.20187      1      1   150.44905     -0.67183    5.95397
# 2          -0.80097      2      2   188.39163     -0.80665    5.83511
# 3          -1.12370      3      3   116.65181     -0.88537    5.91168
# 4          -1.14748      4      4   167.95802     -0.76513    5.72420
# ...             ...    ...    ...         ...          ...        ...
# 10235      -0.90464  10235  10235   129.02872     -0.58512    5.70789
# 10236      -0.87756  10236  10236   103.79202     -0.58467    5.74373
# 10237      -1.08944  10237  10237   116.78804     -0.54508    5.57909
# 10238      -1.49180  10238  10238   160.73715     -0.72962    5.65293
# 10239      -1.63916  10239  10239   182.55465     -0.55643    5.72852
#
#         saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 0     -0.000008 -11.08914  3.359702e-07       0.51495  ...          400.0
# 1     -0.000010 -10.81645  2.716911e-08       0.46190  ...          400.0
# 2     -0.000002  -9.13110  7.064269e-09       0.50410  ...          400.0
# 3     -0.000009  -8.18479  7.572708e-08       0.55495  ...          400.0
# 4     -0.000008  -8.96730  3.264946e-07       0.59118  ...          400.0
# ...         ...       ...           ...           ...  ...            ...
# 10235 -0.000005  -8.25317  8.471420e-08       0.56458  ...          400.0
# 10236 -0.000010 -10.70809  3.054535e-08       0.52812  ...          400.0
# 10237 -0.000008 -11.98562  3.976714e-08       0.57912  ...          400.0
# 10238 -0.000007 -10.87092  7.849774e-08       0.50611  ...          400.0
# 10239 -0.000004 -11.52766  4.115539e-07       0.58006  ...          400.0
#
#         k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 0      0.0154       0.353956            1.636023     3.837999     3.319620
# 1      0.0154       0.353956            1.636023     3.851101     3.147336
# 2      0.0154       0.353956            1.636023     3.826016     3.262648
# 3      0.0154       0.353956            1.636023     3.789609     3.221863
# 4      0.0154       0.353956            1.636023     3.904915     3.273875
# ...       ...            ...                 ...          ...          ...
# 10235  0.0154       0.353956            1.636023     3.758538     3.213001
# 10236  0.0154       0.353956            1.636023     8.967080     7.908745
# 10237  0.0154       0.353956            1.636023     8.967080     7.908745
# 10238  0.0154       0.353956            1.636023     4.461891     3.657107
# 10239  0.0154       0.353956            1.636023     4.928683     4.051808
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 0       49.618089   54.506601                NaN       -0.069883
# 1       42.902760   43.826049                NaN       -0.688116
# 2       39.821782   34.709280                NaN       -0.777284
# 3       39.582469   34.842812                NaN       -0.757561
# 4       40.240922   35.510610                NaN       -0.757607
# ...           ...         ...                ...             ...
# 10235   39.420695   34.505850                NaN       -0.760417
# 10236   47.531264   43.398566                NaN        0.000000
# 10237   51.225762   46.115663                NaN        0.000000
# 10238   42.384748   40.312415                NaN       -0.869840
# 10239   44.121343   38.924140                NaN       -1.056798
#
# [10240 rows x 23 columns]

# %%
df_rmse.sort_values(by = 'rmse_psi_stem')
# Out:
#        phi_leaf_min     id    fid  kappa_stem  psi50_close  root_dist  \
# 10232      -1.64673  10232  10232   121.21728     -0.55186    5.73981
# 10233      -0.51329  10233  10233   164.52049     -0.53674    5.88297
# 10234      -1.42731  10234  10234   103.90206     -0.57831    5.53408
# 10235      -0.90464  10235  10235   129.02872     -0.58512    5.70789
# 10236      -0.87756  10236  10236   103.79202     -0.58467    5.74373
# ...             ...    ...    ...         ...          ...        ...
# 35         -1.82218     35     35   155.21781     -0.70962    5.89500
# 36         -1.80691     36     36   110.64727     -0.66674    5.70901
# 37         -0.72170     37     37   171.55828     -0.69829    5.67550
# 38         -0.61205     38     38   155.31553     -0.52207    5.52045
# 39         -1.27493     39     39   115.19646     -0.69138    5.85705
#
#         saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 10232 -0.000007  -9.99137  1.137410e-06       0.48574  ...          400.0
# 10233 -0.000003  -9.69412  9.520951e-07       0.49922  ...          400.0
# 10234 -0.000002 -11.51410  4.216758e-07       0.53254  ...          400.0
# 10235 -0.000005  -8.25317  8.471420e-08       0.56458  ...          400.0
# 10236 -0.000010 -10.70809  3.054535e-08       0.52812  ...          400.0
# ...         ...       ...           ...           ...  ...            ...
# 35    -0.000003  -8.98023  7.824338e-08       0.57786  ...          400.0
# 36    -0.000010 -11.63570  4.839535e-08       0.50085  ...          400.0
# 37    -0.000006  -8.97450  1.131930e-08       0.48672  ...          400.0
# 38    -0.000003 -11.91073  5.285727e-08       0.51961  ...          400.0
# 39    -0.000009 -10.98770  3.143114e-08       0.52883  ...          400.0
#
#         k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 10232  0.0154       0.353956            1.636023     3.133018     2.799275
# 10233  0.0154       0.353956            1.636023     3.401617     2.884734
# 10234  0.0154       0.353956            1.636023     3.980067     3.304467
# 10235  0.0154       0.353956            1.636023     3.758538     3.213001
# 10236  0.0154       0.353956            1.636023     8.967080     7.908745
# ...       ...            ...                 ...          ...          ...
# 35     0.0154       0.353956            1.636023     3.772671     3.236493
# 36     0.0154       0.353956            1.636023     8.967080     7.908745
# 37     0.0154       0.353956            1.636023     3.914144     3.264730
# 38     0.0154       0.353956            1.636023     8.967080     7.908745
# 39     0.0154       0.353956            1.636023     8.967080     7.908745
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 10232   48.558977   52.251553                NaN       -0.289135
# 10233   42.323347   43.756468                NaN       -0.517712
# 10234   41.205811   38.269310                NaN       -0.732452
# 10235   39.420695   34.505850                NaN       -0.760417
# 10236   47.531264   43.398566                NaN        0.000000
# ...           ...         ...                ...             ...
# 35      39.539254   34.485690                NaN       -0.770373
# 36      42.925921   42.296778                NaN        0.000000
# 37      40.338061   35.898136                NaN       -0.742664
# 38      47.153333   43.190700                NaN        0.000000
# 39      47.324838   43.282700                NaN        0.000000
#
# [10240 rows x 23 columns]

# %%
df_rmse
# Out:
#        k_xylem_sat     id    fid  kappa_stem  psi50_close  root_dist  \
# 0          4.35290      0      0   169.82412     -0.66731    5.97765
# 1          4.20562      1      1   188.61013     -0.66245    5.86741
# 2          2.84888      2      2   184.54530     -0.62806    5.96030
# 3          2.67183      3      3   110.09427     -0.80765    5.79032
# 4          3.75389      4      4   103.77991     -0.58384    5.90243
# ...            ...    ...    ...         ...          ...        ...
# 16379      4.29706  16379  16379   152.64417     -0.62877    5.75528
# 16380      2.79920  16380  16380   168.03452     -0.59352    5.93306
# 16381      2.66716  16381  16381   145.26355     -0.60268    5.94279
# 16382      3.08671  16382  16382   141.61666     -0.54418    5.83114
# 16383      3.04861  16383  16383   136.74805     -0.77236    5.73977
#
#             saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 0     -7.000000e-07  -9.39041  1.611468e-07       0.52800  ...          400.0
# 1     -6.000000e-07  -9.64332  7.766642e-08       0.52813  ...          400.0
# 2     -6.000000e-07  -9.72810  1.245824e-07       0.52054  ...          400.0
# 3     -8.000000e-07  -9.04066  1.549773e-07       0.51879  ...          400.0
# 4     -8.000000e-07  -9.05021  6.130605e-08       0.51287  ...          400.0
# ...             ...       ...           ...           ...  ...            ...
# 16379 -6.000000e-07 -10.62172  5.579829e-08       0.52641  ...          400.0
# 16380 -7.000000e-07  -9.55169  5.224399e-08       0.50254  ...          400.0
# 16381 -6.000000e-07 -10.53278  5.093572e-08       0.52031  ...          400.0
# 16382 -6.000000e-07 -10.64443  1.268865e-07       0.52249  ...          400.0
# 16383 -1.000000e-06  -9.94081  1.491482e-07       0.51771  ...          400.0
#
#         k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 0      0.0154       0.353956            1.636023     3.837999     3.319620
# 1      0.0154       0.118441            0.809608     3.355837     2.946237
# 2      0.0154       0.123783            1.195555     3.527305     3.201936
# 3      0.0154       0.184728            6.969907     3.263561     3.020254
# 4      0.0154       0.153331            4.672751     3.443992     3.016321
# ...       ...            ...                 ...          ...          ...
# 16379  0.0154       0.233571            0.774163     3.845653     3.592818
# 16380  0.0154       0.166594            2.539531     3.543581     3.067933
# 16381  0.0154       0.176377            0.762051     3.995271     3.654752
# 16382  0.0154       0.140557            0.945834     3.942526     3.611216
# 16383  0.0154       0.159096            0.894723     3.307608     3.018451
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 0       49.618089   54.506601                NaN       -0.069883
# 1       37.842331   33.556966           0.274997       -0.589945
# 2       38.659096   35.452115           0.252604       -0.467841
# 3       38.271023   35.478429           0.215575       -0.291826
# 4       38.192492   34.052999           0.220156       -0.447786
# ...           ...         ...                ...             ...
# 16379   39.590737   35.842773           0.267177       -0.827955
# 16380   38.515864   34.562487           0.223632       -0.369454
# 16381   40.238411   36.275003           0.255285       -0.686455
# 16382   40.199683   36.768478           0.245413       -0.718764
# 16383   37.965066   35.108449           0.251525       -0.547374
#
# [16384 rows x 23 columns]

# %%
df_rmse.sort_values(by = 'rmse_gpp_22')
# Out:
#       phi_leaf_min    id   fid  kappa_stem  psi50_close  root_dist   saxtonA  \
# 8845      -2.02452  8845  8845   158.69670     -0.64720    5.98757 -0.000001
# 5473      -1.81365  5473  5473   112.73529     -0.73159    5.53250 -0.000002
# 1080      -2.48009  1080  1080   106.13862     -0.79673    5.62642 -0.000006
# 7772      -2.30863  7772  7772   112.05304     -0.51587    5.78842 -0.000004
# 9128      -1.61873  9128  9128   136.95646     -0.63735    5.93685 -0.000002
# ...            ...   ...   ...         ...          ...        ...       ...
# 4085      -1.53817  4085  4085   115.01889     -0.52358    5.61563 -0.000007
# 38        -0.61205    38    38   155.31553     -0.52207    5.52045 -0.000003
# 4088      -0.56180  4088  4088   158.47161     -0.86108    5.72049 -0.000007
# 36        -1.80691    36    36   110.64727     -0.66674    5.70901 -0.000010
# 33        -0.99047    33    33   144.08176     -0.51706    5.90264 -0.000007
#
#        saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req   k_gdd  \
# 8845  -8.80168  1.081621e-06       0.45251  ...          400.0  0.0154
# 5473  -8.20597  1.856155e-06       0.46973  ...          400.0  0.0154
# 1080  -8.05016  6.555192e-07       0.46599  ...          400.0  0.0154
# 7772  -8.23619  6.570257e-07       0.46303  ...          400.0  0.0154
# 9128  -8.52240  1.702983e-06       0.47221  ...          400.0  0.0154
# ...        ...           ...           ...  ...            ...     ...
# 4085 -11.35601  5.740376e-08       0.48637  ...          400.0  0.0154
# 38   -11.91073  5.285727e-08       0.51961  ...          400.0  0.0154
# 4088 -11.95495  1.406416e-08       0.47898  ...          400.0  0.0154
# 36   -11.63570  4.839535e-08       0.50085  ...          400.0  0.0154
# 33   -11.89527  1.577732e-08       0.59598  ...          400.0  0.0154
#
#       rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  rmse_le_22  \
# 8845       0.353956            1.636023     3.026534     2.887741   44.033555
# 5473       0.353956            1.636023     3.026988     2.893104   44.699952
# 1080       0.353956            1.636023     3.031719     2.884059   44.619838
# 7772       0.353956            1.636023     3.031867     2.880509   43.838402
# 9128       0.353956            1.636023     3.032046     2.884620   45.015104
# ...             ...                 ...          ...          ...         ...
# 4085       0.353956            1.636023     8.967080     7.908745   42.811381
# 38         0.353956            1.636023     8.967080     7.908745   47.153333
# 4088       0.353956            1.636023     8.967080     7.908745   43.080460
# 36         0.353956            1.636023     8.967080     7.908745   42.925921
# 33         0.353956            1.636023     8.967080     7.908745   53.391354
#
#       rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 8845   47.138252                NaN       -0.252713
# 5473   48.034200                NaN       -0.195660
# 1080   47.886172                NaN       -0.209445
# 7772   46.848735                NaN       -0.254639
# 9128   48.398993                NaN       -0.212738
# ...          ...                ...             ...
# 4085   43.150477                NaN        0.000000
# 38     43.190700                NaN        0.000000
# 4088   42.106405                NaN        0.000000
# 36     42.296778                NaN        0.000000
# 33     48.115315                NaN        0.000000
#
# [10240 rows x 23 columns]

# %%
df_rmse.sort_values(by = 'rmse_le_22')
# Out:
#        k_xylem_sat     id    fid  kappa_stem  psi50_close  root_dist  \
# 14069      3.88522  14069  14069   186.60209     -0.88752    5.78016
# 326        4.47264    326    326   158.38812     -0.85151    5.87247
# 2676       4.33401   2676   2676   187.89607     -0.88928    5.69312
# 7302       4.25867   7302   7302   181.75156     -0.84825    5.79178
# 7567       4.34121   7567   7567   175.34472     -0.88698    5.78712
# ...            ...    ...    ...         ...          ...        ...
# 7149       2.53465   7149   7149   127.10584     -0.51455    5.53637
# 9674       2.57505   9674   9674   188.58792     -0.54096    5.63122
# 3229       3.14071   3229   3229   150.42258     -0.51193    5.99209
# 10200      3.45761  10200  10200   147.76850     -0.50454    5.95700
# 0          4.35290      0      0   169.82412     -0.66731    5.97765
#
#             saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 14069 -5.000000e-07  -9.91295  8.551002e-08       0.51360  ...          400.0
# 326   -5.000000e-07  -9.35108  1.088773e-07       0.52699  ...          400.0
# 2676  -6.000000e-07  -9.74981  5.826907e-08       0.50121  ...          400.0
# 7302  -9.000000e-07  -9.69924  6.864125e-08       0.50668  ...          400.0
# 7567  -7.000000e-07  -9.32825  6.840823e-08       0.52162  ...          400.0
# ...             ...       ...           ...           ...  ...            ...
# 7149  -1.000000e-06 -10.88137  7.771306e-08       0.52586  ...          400.0
# 9674  -9.000000e-07 -10.72083  6.047354e-08       0.52863  ...          400.0
# 3229  -7.000000e-07 -10.99751  5.749539e-08       0.52847  ...          400.0
# 10200 -9.000000e-07 -10.93058  5.619996e-08       0.52728  ...          400.0
# 0     -7.000000e-07  -9.39041  1.611468e-07       0.52800  ...          400.0
#
#         k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 14069  0.0154       0.177184            0.899549     3.123553     2.867589
# 326    0.0154       0.133768            0.659302     3.121456     2.853352
# 2676   0.0154       0.144392            0.892106     3.089083     2.859983
# 7302   0.0154       0.176675            0.882875     3.128137     2.878580
# 7567   0.0154       0.173189            0.764240     3.093302     2.893918
# ...       ...            ...                 ...          ...          ...
# 7149   0.0154       0.169522            0.823425     4.364714     3.861811
# 9674   0.0154       0.161812            0.912683     4.334375     3.825185
# 3229   0.0154       0.160447            0.719953     4.379137     3.948013
# 10200  0.0154       0.164741            0.733548     4.388674     3.990965
# 0      0.0154       0.353956            1.636023     3.837999     3.319620
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 14069   36.904186   33.835419           0.304800       -0.426906
# 326     36.924478   33.701373           0.273965       -0.381478
# 2676    36.928541   34.314207           0.297312       -0.362424
# 7302    36.944370   34.084584           0.296032       -0.442736
# 7567    36.946555   33.999798           0.290435       -0.413643
# ...           ...         ...                ...             ...
# 7149    41.365590   37.293262           0.259812       -0.757255
# 9674    41.371679   37.057562           0.268152       -0.724471
# 3229    41.655646   37.180769           0.269937       -0.758469
# 10200   41.722866   37.367945           0.270530       -0.803185
# 0       49.618089   54.506601                NaN       -0.069883
#
# [16384 rows x 23 columns]

# %%
df_rmse.sort_values(by = 'rmse_sapflow_norm')
# Out:
#        k_xylem_sat     id    fid  kappa_stem  psi50_close  root_dist  \
# 12176      4.26969  12176  12176   176.26331     -0.61221    5.75627
# 9207       3.79666   9207   9207   160.23274     -0.67627    5.93146
# 11076      4.49094  11076  11076   117.19017     -0.60727    5.88227
# 757        3.94957    757    757   102.82199     -0.76391    5.68991
# 7562       4.36994   7562   7562   110.47651     -0.60340    5.74570
# ...            ...    ...    ...         ...          ...        ...
# 13754      3.77636  13754  13754   184.73044     -0.88100    5.57353
# 9977       4.26836   9977   9977   187.89048     -0.84568    5.63663
# 9925       3.26209   9925   9925   185.70044     -0.86615    5.91552
# 11162      3.65675  11162  11162   182.37612     -0.89451    5.93418
# 0          4.35290      0      0   169.82412     -0.66731    5.97765
#
#             saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 12176 -9.000000e-07 -10.24597  1.873954e-07       0.50172  ...          400.0
# 9207  -7.000000e-07 -10.31230  1.779818e-07       0.50229  ...          400.0
# 11076 -8.000000e-07 -10.36032  1.489295e-07       0.50619  ...          400.0
# 757   -6.000000e-07 -10.56428  1.910188e-07       0.50846  ...          400.0
# 7562  -7.000000e-07 -10.84154  1.753633e-07       0.50267  ...          400.0
# ...             ...       ...           ...           ...  ...            ...
# 13754 -6.000000e-07 -10.12971  1.212554e-07       0.51930  ...          400.0
# 9977  -6.000000e-07  -9.88632  5.309780e-08       0.50901  ...          400.0
# 9925  -9.000000e-07  -9.76188  5.202793e-08       0.50952  ...          400.0
# 11162 -8.000000e-07 -10.01322  7.206953e-08       0.52148  ...          400.0
# 0     -7.000000e-07  -9.39041  1.611468e-07       0.52800  ...          400.0
#
#         k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 12176  0.0154       0.127843            0.794727     3.319534     2.832869
# 9207   0.0154       0.106320            0.753750     3.277676     2.861373
# 11076  0.0154       0.110281            1.048178     3.370975     2.918976
# 757    0.0154       0.166195            0.820881     3.236718     2.942091
# 7562   0.0154       0.114675            0.912470     3.430642     2.911601
# ...       ...            ...                 ...          ...          ...
# 13754  0.0154       0.259725            1.064222     3.173865     3.033286
# 9977   0.0154       0.244420            1.049126     3.190278     3.034127
# 9925   0.0154       0.296720            1.150178     3.294205     3.068274
# 11162  0.0154       0.403434            1.066882     3.366418     3.108174
# 0      0.0154       0.353956            1.636023     3.837999     3.319620
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 12176   37.618564   35.296235           0.202531       -0.342686
# 9207    37.511793   35.108332           0.202827       -0.365538
# 11076   37.682442   34.542118           0.203042       -0.497539
# 757     37.522061   35.265632           0.203126       -0.471857
# 7562    37.946517   35.096650           0.203250       -0.483829
# ...           ...         ...                ...             ...
# 13754   37.555711   35.217274           0.312128       -0.585261
# 9977    37.543830   34.815296           0.313224       -0.620063
# 9925    37.942332   34.671437           0.313816       -0.679760
# 11162   38.129380   34.343170           0.314282       -0.802843
# 0       49.618089   54.506601                NaN       -0.069883
#
# [16384 rows x 23 columns]

# %%
df_rmse.sort_values(by = 'slope_gpp17-19')
# Out:
#        k_xylem_sat     id    fid  kappa_stem  psi50_close  root_dist  \
# 3700       3.65745   3700   3700   121.36615     -0.88064    5.97018
# 13200      3.89359  13200  13200   104.02112     -0.79316    5.79801
# 5290       3.77989   5290   5290   109.71492     -0.85686    5.86827
# 3766       4.13929   3766   3766   107.54688     -0.69006    5.89984
# 8702       3.31731   8702   8702   111.50427     -0.84337    5.93536
# ...            ...    ...    ...         ...          ...        ...
# 16297      3.09417  16297  16297   115.07635     -0.82708    5.51026
# 15947      3.14499  15947  15947   174.87947     -0.85380    5.54272
# 10178      2.69053  10178  10178   171.49159     -0.85872    5.65443
# 172        3.62902    172    172   170.23639     -0.88572    5.65164
# 0          4.35290      0      0   169.82412     -0.66731    5.97765
#
#             saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 3700  -8.000000e-07 -10.94038  8.756208e-08       0.52755  ...          400.0
# 13200 -1.000000e-06 -10.90544  6.528210e-08       0.52099  ...          400.0
# 5290  -1.000000e-06 -10.95071  9.151053e-08       0.52714  ...          400.0
# 3766  -9.000000e-07 -10.95150  8.223411e-08       0.52792  ...          400.0
# 8702  -9.000000e-07 -10.97855  1.273115e-07       0.52559  ...          400.0
# ...             ...       ...           ...           ...  ...            ...
# 16297 -5.000000e-07  -9.04135  1.550235e-07       0.50140  ...          400.0
# 15947 -7.000000e-07  -9.05081  1.736155e-07       0.50087  ...          400.0
# 10178 -6.000000e-07  -9.00647  1.604066e-07       0.50082  ...          400.0
# 172   -6.000000e-07  -9.08457  1.825027e-07       0.50374  ...          400.0
# 0     -7.000000e-07  -9.39041  1.611468e-07       0.52800  ...          400.0
#
#         k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 3700   0.0154       0.511897            0.982916     3.860313     3.543278
# 13200  0.0154       0.487244            0.799500     3.879346     3.592208
# 5290   0.0154       0.522777            0.887168     3.817940     3.497818
# 3766   0.0154       0.393529            0.780070     4.030682     3.769686
# 8702   0.0154       0.514128            0.846726     3.781704     3.406072
# ...       ...            ...                 ...          ...          ...
# 16297  0.0154       0.262796           21.761280     3.161971     2.822239
# 15947  0.0154       0.236344            8.794140     3.088834     2.890747
# 10178  0.0154       0.249739            9.834075     3.160995     2.844693
# 172    0.0154       0.231204            4.966884     3.110639     2.834407
# 0      0.0154       0.353956            1.636023     3.837999     3.319620
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 3700    39.676707   35.976766           0.276030       -0.999255
# 13200   39.759301   36.244286           0.254191       -0.993245
# 5290    39.482549   35.858181           0.260098       -0.987544
# 3766    40.276111   36.964191           0.259549       -0.986392
# 8702    39.534660   35.942005           0.247066       -0.970274
# ...           ...         ...                ...             ...
# 16297   37.553320   34.606531           0.210045       -0.127240
# 15947   37.823606   35.949160           0.211679       -0.127115
# 10178   37.695404   34.984579           0.212063       -0.126761
# 172     37.515288   35.033700           0.208885       -0.116840
# 0       49.618089   54.506601                NaN       -0.069883
#
# [16384 rows x 23 columns]

# %%
#slice_psi_stem = df_rmse[df_rmse['rmse_psi_stem'] < 0.12]
df_rmse.iloc[[7816, 729, 1873]]
# Out:
#       k_xylem_sat    id   fid  kappa_stem  kappa_leaf    k_latosa       g0  \
# 7816      8.32894  7816  7816   479.42230     0.00384  3793.04989  0.02819
# 729       9.19161   729   729   151.88494     0.00189  4016.03318  0.01239
# 1873      7.03762  1873  1873   239.14073     0.00279  4081.71164  0.03000
#
#            g1  psi50_close  root_dist  ...  slope_leaf_close    g_res  \
# 7816  4.04708     -2.32070    3.61470  ...           3.49947  0.00001
# 729   4.04749     -2.38129    2.66727  ...           1.92751  0.00000
# 1873  3.53622     -2.24308    3.83950  ...           2.85748  0.00000
#
#       rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  rmse_le_22  \
# 7816       0.254685            1.267467     3.621151     3.331374   43.093831
# 729        0.179592            1.099305     3.648614     3.332639   43.441201
# 1873       0.372116            1.081454     3.573063     3.311491   43.055917
#
#       rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 7816   45.183578           0.357550        0.344950
# 729    45.734432           0.232563        0.405473
# 1873   44.770392           0.303777        0.254228
#
# [3 rows x 23 columns]

# %%
slice_psi_stem = df_rmse[df_rmse['rmse_le_24'] < 46.9]
slice_psi_stem.shape
# Out:
# (10239, 23)

# %%
slice_psi_stem = df_rmse[df_rmse['rmse_le_22'] < 43.88]
slice_psi_stem.shape
# Out:
# (10239, 23)

# %%
slice_psi_stem = df_rmse[df_rmse['rmse_gpp_22'] < 3.7]
slice_psi_stem.shape
# Out:
# (5251, 23)

# %%
slice_psi_stem = df_rmse[df_rmse['rmse_gpp_24'] < 3.27]
slice_psi_stem.shape
# Out:
# (9289, 23)

# %%
slice_psi_stem = df_rmse[(df_rmse['rmse_psi_stem'] < 0.12) & (df_rmse['rmse_gpp_24'] < 3.27)]
slice_psi_stem.shape
# Out:
# (0, 16)

# %%
slice_psi_stem = df_rmse[(df_rmse['rmse_psi_stem'] < 0.12) & (df_rmse['rmse_gpp_22'] < 3.63)]
slice_psi_stem.shape
# Out:
# (1368, 23)

# %%
slice_psi_stem = df_rmse[(df_rmse['rmse_psi_stem'] < 0.09) & (df_rmse['rmse_gpp_22'] < 3.63)& (df_rmse['rmse_le_22'] < 43.88)]
slice_psi_stem.shape
slice_psi_stem['fid'].to_list()
# Out:
# []

# %%
slice_psi_stem = df_rmse[(df_rmse['rmse_psi_stem'] < 0.09) & (df_rmse['rmse_gpp_22'] < 3.63)& (df_rmse['rmse_le_22'] < 43.88)]
slice_psi_stem.shape
slice_psi_stem
# Out:
# Empty DataFrame
# Columns: [k_xylem_sat, id, fid, kappa_stem, psi50_close, root_dist, saxtonA, saxtonB, kdiff_sat_sl, theta_sat_sl, root_scale, slope_leaf_close, gdd_t_air_threshold, gdd_t_air_req, k_gdd, rmse_psi_stem, rmse_psi_stem_norm, rmse_gpp_22, rmse_gpp_24, rmse_le_22, rmse_le_24, rmse_sapflow_norm, slope_gpp17-19]
# Index: []
#
# [0 rows x 23 columns]

# %%
slice_psi_stem[['fid', 'rmse_psi_stem','k_xylem_sat', 'kappa_stem', 'kappa_leaf', 'root_dist']].sort_values(by = 'root_dist', ascending=False)['fid'].to_list()
# Out:
# [8635,
#  2739,
#  13454,
#  11833,
#  6415,
#  14475,
#  12545,
#  4272,
#  2834,
#  12739,
#  15962,
#  14426,
#  11843,
#  7251,
#  7912,
#  5702,
#  16294,
#  15671,
#  13467,
#  1723,
#  5113,
#  15723,
#  8247,
#  4693,
#  9946,
#  5275,
#  2877,
#  11590,
#  2120,
#  11447,
#  9703,
#  1663,
#  8269,
#  2281,
#  10532,
#  10033,
#  4914,
#  2214,
#  9769,
#  851,
#  4972,
#  380,
#  6129,
#  8025,
#  5962,
#  7720,
#  8949,
#  6007]

# %%
slice_psi_stem = df_rmse[(df_rmse['slope_gpp17-19']  < -0.2) & (df_rmse['rmse_gpp_22'] < 3.2)]
slice_psi_stem.sort_values(by= 'rmse_gpp_22')[0:30]['fid'].to_list()
# Out:
# [8845,
#  1080,
#  7772,
#  9128,
#  1466,
#  7369,
#  6941,
#  8643,
#  8820,
#  3480,
#  9275,
#  5006,
#  7533,
#  3977,
#  7221,
#  1673,
#  8710,
#  27,
#  3279,
#  8265,
#  165,
#  9384,
#  549,
#  9405,
#  8348,
#  74,
#  7643,
#  7670,
#  3129,
#  9903]

# %%
slice_psi_stem = df_rmse[(df_rmse['slope_gpp17-19'] < -0.2) & (df_rmse['rmse_gpp_22'] < 3.2)&(df_rmse['rmse_psi_stem'] < 0.13)]
slice_psi_stem.sort_values(by= 'slope_gpp17-19')
# Out:
# Empty DataFrame
# Columns: [phi_leaf_min, id, fid, kappa_stem, psi50_close, root_dist, saxtonA, saxtonB, kdiff_sat_sl, theta_sat_sl, root_scale, slope_leaf_close, gdd_t_air_threshold, gdd_t_air_req, k_gdd, rmse_psi_stem, rmse_psi_stem_norm, rmse_gpp_22, rmse_gpp_24, rmse_le_22, rmse_le_24, rmse_sapflow_norm, slope_gpp17-19]
# Index: []
#
# [0 rows x 23 columns]

# %%
slice_psi_stem.sort_values(by= 'slope_gpp17-19')['fid'][0:300:10].to_list()
# Out:
# [7524,
#  4721,
#  2866,
#  310,
#  15478,
#  3331,
#  5995,
#  8648,
#  528,
#  6486,
#  9385,
#  6043,
#  2055,
#  7960,
#  10715,
#  9422,
#  10706,
#  965,
#  9372,
#  8709,
#  13343,
#  15988,
#  4262,
#  15162,
#  15866,
#  4559,
#  8865,
#  5331,
#  1723,
#  13990]

# %%
#slice_psi_stem.sort_values(by = 'rmse_gpp_22')['fid'].to_list()
slice_psi_stem.hist(figsize=(20,20));

# %%
slice_psi_stem.corr("spearman")
# Out:
#                      k_xylem_sat        id       fid  kappa_stem  psi50_close  \
# k_xylem_sat             1.000000  0.069750  0.069750   -0.026836     0.421630
# id                      0.069750  1.000000  1.000000    0.039998     0.002185
# fid                     0.069750  1.000000  1.000000    0.039998     0.002185
# kappa_stem             -0.026836  0.039998  0.039998    1.000000    -0.123143
# psi50_close             0.421630  0.002185  0.002185   -0.123143     1.000000
# root_dist              -0.070021  0.077563  0.077563   -0.058124    -0.031816
# saxtonA                 0.037292  0.023189  0.023189    0.016760    -0.006506
# saxtonB                 0.019631  0.011772  0.011772   -0.226697    -0.257562
# kdiff_sat_sl            0.088538  0.044737  0.044737    0.041964     0.249642
# theta_sat_sl            0.094237 -0.018565 -0.018565   -0.065841    -0.084378
# root_scale             -0.194494  0.021649  0.021649   -0.009451    -0.083642
# slope_leaf_close        0.090898  0.046931  0.046931    0.007559    -0.021443
# gdd_t_air_threshold          NaN       NaN       NaN         NaN          NaN
# gdd_t_air_req          -0.019415 -0.034249 -0.034249   -0.091944     0.108642
# k_gdd                  -0.069413  0.020536  0.020536    0.010478     0.075907
# rmse_psi_stem          -0.030613 -0.028949 -0.028949   -0.298659    -0.403603
# rmse_psi_stem_norm     -0.053501  0.012761  0.012761   -0.617917     0.170428
# rmse_gpp_22            -0.244088 -0.109287 -0.109287   -0.155743     0.415616
# rmse_gpp_24            -0.304226 -0.032846 -0.032846   -0.369708    -0.111568
# rmse_le_22             -0.336323 -0.101300 -0.101300   -0.283572     0.259319
# rmse_le_24             -0.182138  0.031862  0.031862   -0.094504    -0.012664
# rmse_sapflow_norm      -0.067774  0.026756  0.026756    0.752862    -0.498344
# slope_gpp17-19         -0.214857  0.076769  0.076769   -0.036345    -0.255991
#
#                      root_dist   saxtonA   saxtonB  kdiff_sat_sl  \
# k_xylem_sat          -0.070021  0.037292  0.019631      0.088538
# id                    0.077563  0.023189  0.011772      0.044737
# fid                   0.077563  0.023189  0.011772      0.044737
# kappa_stem           -0.058124  0.016760 -0.226697      0.041964
# psi50_close          -0.031816 -0.006506 -0.257562      0.249642
# root_dist             1.000000 -0.061610  0.203670     -0.007069
# saxtonA              -0.061610  1.000000 -0.293170      0.054001
# saxtonB               0.203670 -0.293170  1.000000     -0.472722
# kdiff_sat_sl         -0.007069  0.054001 -0.472722      1.000000
# theta_sat_sl         -0.054259  0.037017  0.474677      0.191821
# root_scale            0.114758  0.069127 -0.026245     -0.113297
# slope_leaf_close     -0.062693 -0.037491  0.321543      0.128655
# gdd_t_air_threshold        NaN       NaN       NaN           NaN
# gdd_t_air_req         0.161257 -0.025704  0.030651      0.002948
# k_gdd                 0.152406 -0.127881 -0.059227     -0.034223
# rmse_psi_stem         0.041290 -0.020898  0.007105     -0.070329
# rmse_psi_stem_norm   -0.025051 -0.010472  0.126026      0.171695
# rmse_gpp_22          -0.007271 -0.027080 -0.256157     -0.012929
# rmse_gpp_24          -0.018418 -0.099135  0.460030     -0.042867
# rmse_le_22           -0.087630 -0.101995 -0.059035      0.118904
# rmse_le_24           -0.084168 -0.186178 -0.132579      0.422307
# rmse_sapflow_norm    -0.031107  0.124104  0.121078     -0.198801
# slope_gpp17-19       -0.025619  0.024381  0.219625      0.026520
#
#                      theta_sat_sl  ...  gdd_t_air_req     k_gdd  \
# k_xylem_sat              0.094237  ...      -0.019415 -0.069413
# id                      -0.018565  ...      -0.034249  0.020536
# fid                     -0.018565  ...      -0.034249  0.020536
# kappa_stem              -0.065841  ...      -0.091944  0.010478
# psi50_close             -0.084378  ...       0.108642  0.075907
# root_dist               -0.054259  ...       0.161257  0.152406
# saxtonA                  0.037017  ...      -0.025704 -0.127881
# saxtonB                  0.474677  ...       0.030651 -0.059227
# kdiff_sat_sl             0.191821  ...       0.002948 -0.034223
# theta_sat_sl             1.000000  ...      -0.013864 -0.147418
# root_scale              -0.063192  ...      -0.044587 -0.004432
# slope_leaf_close        -0.001908  ...      -0.027720 -0.031382
# gdd_t_air_threshold           NaN  ...            NaN       NaN
# gdd_t_air_req           -0.013864  ...       1.000000  0.482585
# k_gdd                   -0.147418  ...       0.482585  1.000000
# rmse_psi_stem           -0.026963  ...       0.067537  0.094596
# rmse_psi_stem_norm      -0.073792  ...       0.047254 -0.000095
# rmse_gpp_22              0.014113  ...       0.027878  0.152660
# rmse_gpp_24              0.058767  ...      -0.019911 -0.002640
# rmse_le_22              -0.108630  ...       0.023167  0.031202
# rmse_le_24              -0.377731  ...      -0.039172  0.043875
# rmse_sapflow_norm        0.161106  ...      -0.098090 -0.008162
# slope_gpp17-19           0.074343  ...      -0.027127 -0.054613
#
#                      rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  \
# k_xylem_sat              -0.030613           -0.053501    -0.244088
# id                       -0.028949            0.012761    -0.109287
# fid                      -0.028949            0.012761    -0.109287
# kappa_stem               -0.298659           -0.617917    -0.155743
# psi50_close              -0.403603            0.170428     0.415616
# root_dist                 0.041290           -0.025051    -0.007271
# saxtonA                  -0.020898           -0.010472    -0.027080
# saxtonB                   0.007105            0.126026    -0.256157
# kdiff_sat_sl             -0.070329            0.171695    -0.012929
# theta_sat_sl             -0.026963           -0.073792     0.014113
# root_scale               -0.018236           -0.019415    -0.060552
# slope_leaf_close          0.095170            0.377025    -0.326767
# gdd_t_air_threshold            NaN                 NaN          NaN
# gdd_t_air_req             0.067537            0.047254     0.027878
# k_gdd                     0.094596           -0.000095     0.152660
# rmse_psi_stem             1.000000            0.234707    -0.012893
# rmse_psi_stem_norm        0.234707            1.000000     0.037729
# rmse_gpp_22              -0.012893            0.037729     1.000000
# rmse_gpp_24               0.099079            0.525663    -0.067057
# rmse_le_22                0.190882            0.445277     0.517324
# rmse_le_24                0.108785            0.481531    -0.195406
# rmse_sapflow_norm        -0.034265           -0.552702    -0.339593
# slope_gpp17-19           -0.328246            0.058153    -0.312302
#
#                      rmse_gpp_24  rmse_le_22  rmse_le_24  rmse_sapflow_norm  \
# k_xylem_sat            -0.304226   -0.336323   -0.182138          -0.067774
# id                     -0.032846   -0.101300    0.031862           0.026756
# fid                    -0.032846   -0.101300    0.031862           0.026756
# kappa_stem             -0.369708   -0.283572   -0.094504           0.752862
# psi50_close            -0.111568    0.259319   -0.012664          -0.498344
# root_dist              -0.018418   -0.087630   -0.084168          -0.031107
# saxtonA                -0.099135   -0.101995   -0.186178           0.124104
# saxtonB                 0.460030   -0.059035   -0.132579           0.121078
# kdiff_sat_sl           -0.042867    0.118904    0.422307          -0.198801
# theta_sat_sl            0.058767   -0.108630   -0.377731           0.161106
# root_scale              0.070484    0.023340    0.035207          -0.055170
# slope_leaf_close        0.699837    0.428661    0.664831           0.178009
# gdd_t_air_threshold          NaN         NaN         NaN                NaN
# gdd_t_air_req          -0.019911    0.023167   -0.039172          -0.098090
# k_gdd                  -0.002640    0.031202    0.043875          -0.008162
# rmse_psi_stem           0.099079    0.190882    0.108785          -0.034265
# rmse_psi_stem_norm      0.525663    0.445277    0.481531          -0.552702
# rmse_gpp_22            -0.067057    0.517324   -0.195406          -0.339593
# rmse_gpp_24             1.000000    0.598945    0.612723          -0.156615
# rmse_le_22              0.598945    1.000000    0.505187          -0.336463
# rmse_le_24              0.612723    0.505187    1.000000          -0.201020
# rmse_sapflow_norm      -0.156615   -0.336463   -0.201020           1.000000
# slope_gpp17-19          0.035559   -0.400788    0.049537          -0.097973
#
#                      slope_gpp17-19
# k_xylem_sat               -0.214857
# id                         0.076769
# fid                        0.076769
# kappa_stem                -0.036345
# psi50_close               -0.255991
# root_dist                 -0.025619
# saxtonA                    0.024381
# saxtonB                    0.219625
# kdiff_sat_sl               0.026520
# theta_sat_sl               0.074343
# root_scale                 0.123448
# slope_leaf_close          -0.162339
# gdd_t_air_threshold             NaN
# gdd_t_air_req             -0.027127
# k_gdd                     -0.054613
# rmse_psi_stem             -0.328246
# rmse_psi_stem_norm         0.058153
# rmse_gpp_22               -0.312302
# rmse_gpp_24                0.035559
# rmse_le_22                -0.400788
# rmse_le_24                 0.049537
# rmse_sapflow_norm         -0.097973
# slope_gpp17-19             1.000000
#
# [23 rows x 23 columns]

# %%
slice_psi_stem = df_rmse[(df_rmse['slope_gpp17-19'] < -0.3) & (df_rmse['rmse_gpp_22'] < 3.3)]
slice_psi_stem.sort_values(by = 'rmse_gpp_22')
# Out:
#        k_xylem_sat     id    fid  kappa_stem  psi50_close  root_dist  \
# 27524      3.90185  27524  27524   177.61355     -0.72320    5.44393
# 16178      3.68038  16178  16178   174.73736     -0.73450    5.34246
# 2438       3.89867   2438   2438   181.39520     -0.70879    5.72652
# 5728       3.81983   5728   5728   144.02710     -0.70754    5.37758
# 12425      3.97116  12425  12425   167.49392     -0.73906    5.31052
# ...            ...    ...    ...         ...          ...        ...
# 5040       3.97526   5040   5040   135.39975     -0.74737    5.35908
# 31094      3.89726  31094  31094   162.32706     -0.71129    5.54413
# 64         3.83193     64     64   163.78392     -0.72714    5.61895
# 7478       3.88376   7478   7478   177.08999     -0.71863    5.71442
# 5127       3.76362   5127   5127   164.84910     -0.66933    5.58608
#
#             saxtonA   saxtonB  kdiff_sat_sl  theta_sat_sl  ...  gdd_t_air_req  \
# 27524 -4.000000e-07  -9.84137  1.108768e-07       0.50001  ...      378.48330
# 16178 -2.000000e-07 -10.30274  3.157777e-07       0.51523  ...      344.25126
# 2438  -3.000000e-07 -10.01457  1.883359e-07       0.50511  ...      376.63875
# 5728  -6.000000e-07 -10.31744  2.152799e-07       0.50028  ...      386.65354
# 12425 -9.000000e-07 -10.15822  4.541845e-07       0.52543  ...      413.92728
# ...             ...       ...           ...           ...  ...            ...
# 5040  -5.000000e-07  -9.63962  2.670183e-07       0.51617  ...      413.75126
# 31094 -9.000000e-07  -9.97675  3.958175e-07       0.50953  ...      388.03315
# 64    -3.000000e-07  -9.29951  1.666868e-07       0.54179  ...      384.60065
# 7478  -5.000000e-07  -9.86459  1.641952e-07       0.51248  ...      318.92019
# 5127  -4.000000e-07  -9.49669  1.650258e-07       0.52177  ...      367.70639
#
#          k_gdd  rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 27524  0.01342       0.130548            1.189367     3.152135     2.944176
# 16178  0.01289       0.143260            1.530917     3.159729     2.943016
# 2438   0.01264       0.142066            1.410336     3.162264     2.926756
# 5728   0.01419       0.127578            1.546594     3.175359     2.986862
# 12425  0.01331       0.103428            0.852649     3.181482     2.998075
# ...        ...            ...                 ...          ...          ...
# 5040   0.01392       0.127868            2.313683     3.297521     2.980820
# 31094  0.01282       0.142537            0.672347     3.297645     2.981643
# 64     0.01345       0.118273            0.744156     3.298190     3.037623
# 7478   0.01436       0.106727            0.731450     3.298965     2.950944
# 5127   0.01202       0.121151            1.592600     3.299436     2.952881
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 27524   37.587229   35.205434           0.259355       -0.324919
# 16178   37.707926   35.349486           0.254273       -0.300210
# 2438    37.577141   35.170586           0.244839       -0.320046
# 5728    38.019203   36.867781           0.207910       -0.337316
# 12425   37.900297   36.657864           0.237993       -0.381580
# ...           ...         ...                ...             ...
# 5040    37.854179   34.984124           0.230531       -0.388609
# 31094   38.278587   36.514450           0.251563       -0.529659
# 64      37.921996   34.258132           0.231028       -0.479772
# 7478    37.527980   34.976939           0.262156       -0.376337
# 5127    37.835373   34.168110           0.239869       -0.368155
#
# [105 rows x 23 columns]

# %%
slice_psi_stem = df_rmse[(df_rmse['slope_gpp17-19'] < -0.1) &(df_rmse['slope_gpp17-19'] > -0.4)]
print(slice_psi_stem.shape)
y = slice_psi_stem.mean().to_frame()
slice_psi_stem.sort_values(by = 'slope_gpp17-19')['fid'].to_list()
#slice_psi_stem.sort_values(by = 'slope_gpp17-19')
# Out:
# (2597, 18)
# [3160,
#  6813,
#  3822,
#  3346,
#  4417,
#  5857,
#  201,
#  5820,
#  5700,
#  1244,
#  2163,
#  955,
#  1236,
#  2490,
#  3356,
#  2603,
#  4916,
#  6468,
#  7196,
#  910,
#  2420,
#  102,
#  2102,
#  2857,
#  5021,
#  6566,
#  5912,
#  6731,
#  2030,
#  6423,
#  6761,
#  5723,
#  7163,
#  6141,
#  3997,
#  6201,
#  3002,
#  811,
#  1610,
#  2736,
#  1407,
#  5270,
#  7242,
#  984,
#  4447,
#  6179,
#  1157,
#  1281,
#  5146,
#  6748,
#  2617,
#  7207,
#  2428,
#  1773,
#  7341,
#  460,
#  5736,
#  7473,
#  3680,
#  1606,
#  2139,
#  6253,
#  6292,
#  4659,
#  3682,
#  5360,
#  3348,
#  6263,
#  4050,
#  3223,
#  4200,
#  1086,
#  120,
#  3289,
#  2220,
#  939,
#  6422,
#  7465,
#  7625,
#  732,
#  4209,
#  6734,
#  6907,
#  6497,
#  5563,
#  1373,
#  2385,
#  2344,
#  2390,
#  800,
#  792,
#  6341,
#  1432,
#  55,
#  4570,
#  7225,
#  2541,
#  7526,
#  2254,
#  2485,
#  850,
#  6320,
#  5768,
#  7333,
#  2078,
#  7161,
#  4706,
#  4518,
#  4487,
#  1573,
#  1522,
#  6537,
#  2621,
#  3363,
#  4837,
#  4754,
#  366,
#  4814,
#  1906,
#  4975,
#  271,
#  2812,
#  1596,
#  6608,
#  5812,
#  3395,
#  5915,
#  7147,
#  601,
#  1163,
#  3065,
#  400,
#  7123,
#  855,
#  6499,
#  2570,
#  5328,
#  2393,
#  1776,
#  3749,
#  5985,
#  1160,
#  1908,
#  6322,
#  1559,
#  5944,
#  1969,
#  1454,
#  6735,
#  2553,
#  606,
#  2235,
#  4653,
#  1865,
#  5724,
#  884,
#  2147,
#  2186,
#  2376,
#  3235,
#  2944,
#  2806,
#  1665,
#  4806,
#  7648,
#  4080,
#  4807,
#  6993,
#  5691,
#  3903,
#  4541,
#  6934,
#  7371,
#  1339,
#  4778,
#  6236,
#  5989,
#  7092,
#  468,
#  3016,
#  536,
#  4218,
#  4604,
#  1957,
#  1889,
#  7280,
#  3453,
#  3911,
#  2101,
#  6920,
#  6999,
#  3747,
#  6895,
#  5030,
#  3020,
#  3419,
#  3350,
#  6321,
#  6615,
#  1521,
#  3645,
#  4286,
#  7332,
#  6587,
#  3834,
#  6165,
#  2244,
#  2470,
#  1991,
#  228,
#  5035,
#  4299,
#  3564,
#  2196,
#  6250,
#  6929,
#  3518,
#  6782,
#  4716,
#  630,
#  1827,
#  7612,
#  4789,
#  6216,
#  5188,
#  1135,
#  233,
#  2973,
#  5473,
#  1909,
#  3193,
#  2561,
#  6007,
#  966,
#  4894,
#  3161,
#  5994,
#  247,
#  3960,
#  1112,
#  2132,
#  5607,
#  3491,
#  4539,
#  3806,
#  3339,
#  2329,
#  2864,
#  5344,
#  4796,
#  5385,
#  287,
#  3162,
#  96,
#  3855,
#  7128,
#  3111,
#  3122,
#  5830,
#  556,
#  770,
#  4560,
#  1805,
#  4072,
#  4594,
#  5798,
#  1121,
#  3968,
#  419,
#  2987,
#  3790,
#  5833,
#  3839,
#  3830,
#  2646,
#  5015,
#  5715,
#  6736,
#  7007,
#  5228,
#  2493,
#  6561,
#  5813,
#  1837,
#  258,
#  5918,
#  4039,
#  6407,
#  4152,
#  1367,
#  5838,
#  3457,
#  5696,
#  5136,
#  3433,
#  3892,
#  4090,
#  5788,
#  3027,
#  2920,
#  2727,
#  4375,
#  2157,
#  7069,
#  3610,
#  1266,
#  405,
#  416,
#  2986,
#  1667,
#  7481,
#  2885,
#  1147,
#  1966,
#  3810,
#  6308,
#  3763,
#  4038,
#  486,
#  586,
#  6831,
#  5581,
#  1803,
#  5348,
#  1894,
#  4699,
#  5924,
#  1463,
#  2460,
#  4125,
#  5287,
#  4408,
#  3774,
#  816,
#  1518,
#  6487,
#  4033,
#  4963,
#  4765,
#  6003,
#  1563,
#  3844,
#  6419,
#  5436,
#  6436,
#  3317,
#  3783,
#  6212,
#  7300,
#  7102,
#  3417,
#  3035,
#  7641,
#  7117,
#  7362,
#  76,
#  2340,
#  756,
#  6799,
#  6710,
#  6548,
#  1446,
#  5164,
#  629,
#  407,
#  5084,
#  180,
#  6262,
#  1568,
#  3407,
#  6486,
#  3559,
#  503,
#  4479,
#  4491,
#  1569,
#  256,
#  851,
#  7312,
#  2952,
#  2531,
#  5019,
#  1868,
#  6312,
#  1324,
#  140,
#  6854,
#  1291,
#  6398,
#  7260,
#  1635,
#  6601,
#  3549,
#  2310,
#  3323,
#  2967,
#  4217,
#  325,
#  3967,
#  455,
#  6470,
#  576,
#  2179,
#  4522,
#  1301,
#  4715,
#  3142,
#  4251,
#  5770,
#  1421,
#  3786,
#  6682,
#  4746,
#  4725,
#  1217,
#  2774,
#  7654,
#  442,
#  4738,
#  7205,
#  6547,
#  345,
#  6701,
#  6186,
#  1452,
#  2682,
#  3264,
#  2240,
#  5859,
#  5559,
#  7043,
#  6080,
#  3088,
#  994,
#  2189,
#  6834,
#  4230,
#  30,
#  5265,
#  1743,
#  5758,
#  6063,
#  3741,
#  4824,
#  5389,
#  5962,
#  1982,
#  4382,
#  5117,
#  3384,
#  6480,
#  523,
#  1581,
#  5093,
#  1482,
#  5482,
#  2870,
#  6275,
#  4983,
#  5186,
#  849,
#  1989,
#  2882,
#  3536,
#  7478,
#  7039,
#  2145,
#  2979,
#  3320,
#  663,
#  2918,
#  3799,
#  3414,
#  3199,
#  4652,
#  2750,
#  3007,
#  3010,
#  5296,
#  5597,
#  6225,
#  5692,
#  2508,
#  2785,
#  6668,
#  7631,
#  2970,
#  753,
#  7278,
#  3944,
#  2136,
#  2014,
#  6546,
#  3727,
#  7660,
#  7061,
#  207,
#  1480,
#  2566,
#  7420,
#  4799,
#  4803,
#  4710,
#  7619,
#  7458,
#  690,
#  527,
#  1474,
#  2232,
#  7133,
#  964,
#  4857,
#  7006,
#  815,
#  5839,
#  1451,
#  4882,
#  5526,
#  4404,
#  4829,
#  581,
#  4783,
#  6421,
#  3939,
#  5209,
#  2463,
#  3755,
#  2077,
#  5062,
#  1459,
#  2863,
#  4111,
#  3425,
#  2504,
#  4422,
#  3140,
#  763,
#  4040,
#  2807,
#  1145,
#  6545,
#  2156,
#  412,
#  1492,
#  4434,
#  5435,
#  2321,
#  144,
#  7452,
#  2160,
#  6618,
#  1954,
#  4312,
#  2057,
#  557,
#  3200,
#  5544,
#  2511,
#  7306,
#  2348,
#  1729,
#  2593,
#  5928,
#  2161,
#  2764,
#  7568,
#  6551,
#  6491,
#  5614,
#  1671,
#  423,
#  4029,
#  5887,
#  793,
#  5158,
#  6494,
#  5534,
#  1601,
#  3957,
#  6509,
#  6646,
#  5988,
#  509,
#  1287,
#  1901,
#  5686,
#  5754,
#  7665,
#  5708,
#  7396,
#  7343,
#  1777,
#  475,
#  564,
#  2707,
#  4868,
#  7436,
#  705,
#  3462,
#  4573,
#  748,
#  4085,
#  1632,
#  2705,
#  4402,
#  7188,
#  4206,
#  1379,
#  7164,
#  907,
#  2668,
#  5586,
#  7042,
#  2712,
#  6379,
#  3961,
#  1713,
#  5430,
#  7645,
#  4087,
#  2454,
#  5892,
#  735,
#  6879,
#  40,
#  6412,
#  4929,
#  694,
#  4089,
#  2673,
#  2184,
#  771,
#  1278,
#  6073,
#  5380,
#  1034,
#  5485,
#  1919,
#  4051,
#  4672,
#  6010,
#  2843,
#  2745,
#  127,
#  5461,
#  5546,
#  7443,
#  7376,
#  4384,
#  4294,
#  6904,
#  5671,
#  3772,
#  1531,
#  1524,
#  2925,
#  2357,
#  1351,
#  3281,
#  4399,
#  6064,
#  6991,
#  5730,
#  6680,
#  3219,
#  2234,
#  7499,
#  2260,
#  7108,
#  4580,
#  2770,
#  7606,
#  4946,
#  4368,
#  5491,
#  7245,
#  1284,
#  572,
#  2294,
#  563,
#  5193,
#  7054,
#  1951,
#  4728,
#  4489,
#  7198,
#  2679,
#  4683,
#  4870,
#  963,
#  5454,
#  6214,
#  2642,
#  2312,
#  1792,
#  7153,
#  5275,
#  7202,
#  4472,
#  3268,
#  1542,
#  4555,
#  7599,
#  4742,
#  1000,
#  7609,
#  1205,
#  1493,
#  2644,
#  4260,
#  6987,
#  4762,
#  530,
#  6928,
#  2264,
#  6755,
#  1481,
#  762,
#  2575,
#  5925,
#  5483,
#  7429,
#  3190,
#  7355,
#  6772,
#  1212,
#  5693,
#  1580,
#  5484,
#  3015,
#  2935,
#  3971,
#  1359,
#  216,
#  3297,
#  828,
#  4303,
#  6294,
#  5828,
#  4724,
#  1419,
#  7311,
#  6723,
#  24,
#  719,
#  5904,
#  5302,
#  15,
#  7442,
#  7415,
#  5986,
#  4828,
#  12,
#  6217,
#  4180,
#  5260,
#  4635,
#  6637,
#  2974,
#  6084,
#  7234,
#  2584,
#  4301,
#  7542,
#  3687,
#  7091,
#  411,
#  462,
#  6718,
#  3612,
#  1760,
#  5479,
#  1929,
#  7150,
#  5897,
#  1390,
#  4193,
#  687,
#  821,
#  4291,
#  1892,
#  2378,
#  58,
#  707,
#  6438,
#  2667,
#  835,
#  174,
#  7363,
#  7184,
#  6198,
#  2233,
#  1120,
#  1731,
#  2726,
#  5199,
#  6542,
#  4826,
#  4995,
#  6913,
#  1258,
#  7351,
#  1372,
#  3394,
#  1674,
#  3484,
#  6016,
#  882,
#  2629,
#  2224,
#  1514,
#  1457,
#  4572,
#  2969,
#  3646,
#  3152,
#  3377,
#  1132,
#  7438,
#  2415,
#  3940,
#  2792,
#  4025,
#  1122,
#  7670,
#  7165,
#  5706,
#  2076,
#  4283,
#  5761,
#  308,
#  7590,
#  1041,
#  2706,
#  1437,
#  4638,
#  3004,
#  3861,
#  4752,
#  607,
#  3295,
#  51,
#  6881,
#  3595,
#  5645,
#  105,
#  4622,
#  4467,
#  4729,
#  2011,
#  1343,
#  7408,
#  561,
#  4214,
#  516,
#  1197,
#  2897,
#  3563,
#  7309,
#  3760,
#  742,
#  1798,
#  5498,
#  1979,
#  19,
#  3779,
#  204,
#  380,
#  3935,
#  1781,
#  4094,
#  1579,
#  5000,
#  386,
#  6645,
#  7286,
#  1841,
#  1401,
#  5524,
#  4007,
#  3897,
#  989,
#  4848,
#  7229,
#  3019,
#  3423,
#  4744,
#  2013,
#  5896,
#  1020,
#  6570,
#  5157,
#  721,
#  3034,
#  2672,
#  554,
#  4731,
#  3544,
#  740,
#  1472,
#  1063,
#  3120,
#  5712,
#  2392,
#  415,
#  2424,
#  4904,
#  3380,
#  5398,
#  7254,
#  1849,
#  5397,
#  3818,
#  2899,
#  6364,
#  5901,
#  4231,
#  3101,
#  4897,
#  3497,
#  6215,
#  5598,
#  6315,
#  4189,
#  6770,
#  5575,
#  3270,
#  2968,
#  3578,
#  2474,
#  6868,
#  3623,
#  2419,
#  5997,
#  1306,
#  2559,
#  553,
#  6355,
#  1530,
#  1655,
#  3176,
#  2710,
#  6997,
#  716,
#  1517,
#  7203,
#  3871,
#  4880,
#  4612,
#  124,
#  7118,
#  734,
#  3787,
#  4006,
#  2512,
#  941,
#  6450,
#  2808,
#  1692,
#  2106,
#  3924,
#  4392,
#  6066,
#  280,
#  3795,
#  5823,
#  3321,
#  2830,
#  7100,
#  2614,
#  2487,
#  7010,
#  2948,
#  4207,
#  5358,
#  2388,
#  962,
#  3492,
#  1796,
#  3632,
#  5861,
#  7378,
#  7512,
#  6795,
#  805,
#  3952,
#  6430,
#  4623,
#  1888,
#  476,
#  7104,
#  359,
#  5258,
#  5354,
#  38,
#  7382,
#  5145,
#  7387,
#  351,
#  5674,
#  ...]

# %%
slice_psi_stem = df_rmse[(df_rmse['rmse_psi_stem'] < 0.1) & (df_rmse['rmse_gpp_22'] < 3.8)]
print(slice_psi_stem.shape)
x = slice_psi_stem.mean().to_frame()
# Out:
# (12, 23)

# %%
pd.concat([x,y], axis = 1)
# Out:
#                               0             0
# k_xylem_sat            1.632756  1.392083e+00
# id                  3954.750000  3.739402e+03
# fid                 3954.750000  3.739402e+03
# kappa_stem           337.379506  5.743487e+02
# kappa_leaf             0.004866  4.757350e-03
# k_latosa            4378.037441  4.483900e+03
# g0                     0.004741  5.667692e-03
# g1                     3.991393  4.040158e+00
# psi50_close           -2.287761 -2.227933e+00
# root_dist              2.613124  5.958142e+00
# silt                   0.331055  3.122174e-01
# sand                   0.207542  1.950458e-01
# root_scale            30.707322  1.434288e+01
# slope_leaf_close       3.153100  3.246741e+00
# g_res                  0.000016  1.356974e-05
# rmse_psi_stem          0.096357  1.480431e+00
# rmse_psi_stem_norm     0.867331  2.729268e+10
# rmse_gpp_22            3.588269  3.654223e+00
# rmse_gpp_24            3.360460  3.436899e+00
# rmse_le_22            42.927661  4.186428e+01
# rmse_le_24            45.272089  4.383088e+01
# rmse_sapflow_norm      0.257665  3.625597e-01
# slope_gpp17-19         0.378754 -1.520980e-01

# %%
slice_psi_stem = df_rmse[(df_rmse['rmse_psi_stem'] < 0.12) & (df_rmse['rmse_gpp_24'] < 3.27)& (df_rmse['rmse_le_24'] < 46.9)& (df_rmse['kappa_stem'] < 146.9)]
print(slice_psi_stem.shape)
slice_psi_stem
# Out:
# (0, 18)
# Empty DataFrame
# Columns: [k_xylem_sat, id, fid, kappa_stem, psi50_close, root_dist, silt, sand, root_scale, slope_leaf_close, rmse_psi_stem, rmse_psi_stem_norm, rmse_gpp_22, rmse_gpp_24, rmse_le_22, rmse_le_24, rmse_sapflow_norm, slope_gpp17-19]
# Index: []

# %%
df_rmse['rmse_psi_stem'] < 0.1
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 7675    False
# 7676    False
# 7677    False
# 7678    False
# 7679    False
# Name: rmse_psi_stem, Length: 7680, dtype: bool

# %%
slice_psi_stem = df_rmse[(df_rmse['slope_gpp17-19'] < -0.1) &(df_rmse['slope_gpp17-19'] > -0.5)]
slice_psi_stem.sort_values(by = 'slope_gpp17-19')
# Out:
#        k_xylem_sat     id    fid  kappa_stem  kappa_leaf    k_latosa       g0  \
# 3050       7.12663   3050   3050   181.79840     0.00129  4975.72012  0.01657
# 16317      7.36067  16317  16317   379.47151     0.00191  3726.30267  0.02566
# 8220       7.19042   8220   8220   142.77323     0.00190  3457.81458  0.02105
# 15476      5.10867  15476  15476   108.23469     0.00106  3388.17495  0.02737
# 14592      5.68199  14592  14592   178.28710     0.00096  3305.15757  0.02782
# ...            ...    ...    ...         ...         ...         ...      ...
# 15556      6.24602  15556  15556   161.91849     0.00192  4552.62436  0.01466
# 15238      2.73490  15238  15238   132.60065     0.00205  4844.32529  0.00878
# 11441      6.62456  11441  11441   319.65484     0.00170  4403.28375  0.02086
# 1267       5.44054   1267   1267   311.33566     0.00973  4562.75088  0.00763
# 5525       2.65084   5525   5525   390.90746     0.00094  4978.87963  0.02963
#
#             g1  psi50_close  root_dist  ...  slope_leaf_close    g_res  \
# 3050   4.18625     -2.11064    6.07120  ...           2.42946  0.00000
# 16317  4.48837     -2.22848    4.26581  ...           3.80576  0.00013
# 8220   4.06892     -2.34157    6.39746  ...           3.99327  0.00000
# 15476  3.58814     -2.13659    5.45557  ...           3.83835  0.00000
# 14592  3.63422     -2.14758    6.43853  ...           2.17614  0.00003
# ...        ...          ...        ...  ...               ...      ...
# 15556  4.44771     -2.26033    5.63616  ...           2.75917  0.00000
# 15238  4.32299     -2.42628    6.19859  ...           2.97350  0.00004
# 11441  4.29294     -2.09868    6.31746  ...           3.26080  0.00000
# 1267   4.07190     -2.00118    4.69115  ...           3.17369  0.00013
# 5525   4.47693     -2.44565    5.61457  ...           3.50935  0.00000
#
#        rmse_psi_stem  rmse_psi_stem_norm  rmse_gpp_22  rmse_gpp_24  \
# 3050        1.886025            1.303184     3.621833     3.450263
# 16317       1.744992            1.508668     3.674824     3.316684
# 8220        2.026807            1.283532     3.847743     3.471572
# 15476       1.634213            1.185986     3.826736     3.312410
# 14592       1.781059            1.215818     3.903474     3.345852
# ...              ...                 ...          ...          ...
# 15556       1.679320            1.355636     3.476238     3.338658
# 15238       1.729567            1.301366     3.457513     3.352219
# 11441       1.383721            1.473296     3.503242     3.329053
# 1267        1.398537            1.459052     3.501019     3.315061
# 5525        1.191052            1.276140     3.424449     3.415855
#
#        rmse_le_22  rmse_le_24  rmse_sapflow_norm  slope_gpp17-19
# 3050    41.744208   43.302107           0.274024       -0.494416
# 16317   41.902701   44.006849           0.381554       -0.462265
# 8220    41.510224   42.880313           0.268770       -0.427161
# 15476   41.696434   42.856126           0.249182       -0.388104
# 14592   42.181743   43.384342           0.271171       -0.376869
# ...           ...         ...                ...             ...
# 15556   42.514716   45.140637           0.311842       -0.101928
# 15238   41.701376   44.051572           0.258285       -0.101269
# 11441   42.071607   44.102831           0.316309       -0.101193
# 1267    41.103466   42.996485           0.354146       -0.100636
# 5525    45.064102   48.332269           0.353084       -0.100428
#
# [128 rows x 23 columns]

# %%
# Out:
#        k_xylem_sat            id           fid  kappa_stem  kappa_leaf  \
# count   128.000000    128.000000    128.000000  128.000000  128.000000
# mean      6.183293   8253.328125   8253.328125  337.249592    0.003079
# std       2.098295   4981.635748   4981.635748  109.616285    0.002441
# min       2.553800     19.000000     19.000000  101.825890    0.000550
# 25%       4.503705   4087.750000   4087.750000  239.114008    0.001385
# 50%       6.176820   7949.000000   7949.000000  364.173265    0.002280
# 75%       8.255395  12791.500000  12791.500000  423.129230    0.003398
# max       9.473780  16317.000000  16317.000000  498.803430    0.009730
#
#           k_latosa          g0          g1  psi50_close   root_dist  ...  \
# count   128.000000  128.000000  128.000000   128.000000  128.000000  ...
# mean   4312.460016    0.016151    4.158582    -2.200374    5.477713  ...
# std     467.656887    0.007160    0.283818     0.135668    0.870433  ...
# min    3305.157570    0.005350    3.511700    -2.498870    2.872550  ...
# 25%    3962.003068    0.009692    4.047555    -2.296867    5.011245  ...
# 50%    4402.748030    0.015530    4.221305    -2.203435    5.633255  ...
# 75%    4689.592932    0.021410    4.399390    -2.081593    6.160592  ...
# max    4988.816660    0.029910    4.494640    -2.001180    6.498610  ...
#
#        slope_leaf_close       g_res  rmse_psi_stem  rmse_psi_stem_norm  \
# count        128.000000  128.000000     128.000000          128.000000
# mean           2.828006    0.000059       1.601844            1.439745
# std            0.731041    0.000138       0.240179            0.082969
# min            1.178510    0.000000       0.867407            1.125570
# 25%            2.283243    0.000000       1.479921            1.407203
# 50%            2.952775    0.000010       1.636125            1.463343
# 75%            3.395212    0.000043       1.771357            1.496977
# max            3.993270    0.001070       2.131521            1.542873
#
#        rmse_gpp_22  rmse_gpp_24  rmse_le_22  rmse_le_24  rmse_sapflow_norm  \
# count   128.000000   128.000000  128.000000  128.000000         128.000000
# mean      3.579033     3.322312   41.838605   43.735401           0.343497
# std       0.106221     0.039478    0.723023    1.099291           0.038095
# min       3.399654     3.232545   40.671598   41.836024           0.216230
# 25%       3.499443     3.295305   41.332215   42.958789           0.320309
# 50%       3.558010     3.318647   41.694507   43.615643           0.358493
# 75%       3.633161     3.349883   42.282513   44.378341           0.371531
# max       3.903474     3.471572   45.064102   48.332269           0.387675
#
#        slope_gpp17-19
# count      128.000000
# mean        -0.180855
# std          0.082110
# min         -0.494416
# 25%         -0.208726
# 50%         -0.150278
# 75%         -0.120856
# max         -0.100428
#
# [8 rows x 23 columns]

# %%
slice_psi_stem.sort_values(by = 'rmse_psi_stem', ascending=False)['fid'].to_list()
# Out:
# [4500,
#  627,
#  12283,
#  3609,
#  15405,
#  3668,
#  7024,
#  1885,
#  4878,
#  8000,
#  13183,
#  9586,
#  11197,
#  6050,
#  7527,
#  11823,
#  13293,
#  5121,
#  10434,
#  11336,
#  157,
#  6801,
#  5289,
#  15197,
#  16348,
#  15201,
#  7086,
#  4310,
#  5195,
#  8556,
#  9535,
#  15691,
#  1632,
#  14985,
#  1556,
#  10872,
#  2581,
#  4763,
#  1194,
#  14746,
#  11448,
#  15062,
#  14805,
#  4970,
#  12127,
#  2579,
#  3058,
#  2210,
#  11083,
#  13774,
#  12171,
#  5757,
#  632,
#  3664,
#  1770,
#  1094,
#  2322,
#  9941,
#  9643,
#  2475,
#  8665,
#  7131,
#  5476,
#  11688,
#  6101,
#  11897,
#  14544,
#  1862,
#  6982,
#  3470,
#  7735,
#  466,
#  9897,
#  5026,
#  2531,
#  8284,
#  3194,
#  6816,
#  5145,
#  6998,
#  1458,
#  11399,
#  10628,
#  13935,
#  2736,
#  4622,
#  7427,
#  15648,
#  4224,
#  8285,
#  15961,
#  1311,
#  12294,
#  10543,
#  8524,
#  346,
#  4703,
#  4116,
#  11248,
#  3196,
#  11937,
#  14464,
#  6435,
#  10906,
#  11288,
#  397,
#  7708,
#  15574,
#  15256,
#  12537,
#  6817,
#  11199,
#  3405,
#  11513,
#  4318,
#  1423,
#  9395,
#  13076,
#  2883,
#  6315,
#  9187,
#  2927,
#  631,
#  10294,
#  15494,
#  14704,
#  10128,
#  9362,
#  15974,
#  7260,
#  2587,
#  4761,
#  555,
#  7923,
#  2098,
#  815,
#  5826,
#  12924,
#  2121,
#  1792,
#  5594,
#  6192,
#  3867,
#  14438,
#  1732,
#  7268,
#  8605,
#  2928,
#  14387,
#  15241,
#  7916,
#  10322,
#  275,
#  5482,
#  7553,
#  6128,
#  2371,
#  5025,
#  1138,
#  2190,
#  7365,
#  9204,
#  14735,
#  6121,
#  9929,
#  9182,
#  7536,
#  2620,
#  5561,
#  1904,
#  6695,
#  13919,
#  13538,
#  2370,
#  10385,
#  8101,
#  8038,
#  8753,
#  11088,
#  3,
#  15328,
#  12647,
#  15366,
#  4430,
#  8974,
#  16089,
#  10489,
#  11579,
#  6742,
#  16079,
#  4645,
#  4024,
#  14951,
#  2664,
#  5115,
#  13776,
#  4588,
#  2281,
#  9527,
#  15220,
#  374,
#  3294,
#  10365,
#  10304,
#  7033,
#  9132,
#  14987,
#  2172,
#  15849,
#  15508,
#  6741,
#  3917,
#  5590,
#  15070,
#  6717,
#  13230,
#  11261,
#  4603,
#  10317,
#  10772,
#  6230,
#  14528,
#  11494,
#  9584,
#  3461,
#  8739,
#  13125,
#  16325,
#  193,
#  15596,
#  6471,
#  13647,
#  7433,
#  7050,
#  3229,
#  2922,
#  14633,
#  9483,
#  12754,
#  11792,
#  5059,
#  12178,
#  3968,
#  11931,
#  9955,
#  1743,
#  8704,
#  1385,
#  16226,
#  13219,
#  12564,
#  13377,
#  4214,
#  13731,
#  4857,
#  11232,
#  2970,
#  380,
#  9881,
#  9201,
#  3706,
#  5150,
#  11081,
#  4914,
#  4903,
#  13583,
#  12781,
#  9592,
#  12046,
#  13250,
#  12228,
#  4270,
#  12050,
#  14677,
#  14646,
#  1157,
#  1614,
#  8619,
#  11148,
#  13684,
#  2687,
#  4140,
#  915,
#  1400,
#  4399,
#  4869,
#  7200,
#  6385,
#  6795,
#  11311,
#  11050,
#  12236,
#  11850,
#  15770,
#  9825,
#  10627,
#  14370,
#  8510,
#  12132,
#  11576,
#  13243,
#  7591,
#  8852,
#  4020,
#  5962,
#  5495,
#  5325,
#  15156,
#  904,
#  10115,
#  7401,
#  4930,
#  9963,
#  13195,
#  9746,
#  6298,
#  9712,
#  8745,
#  11113,
#  4880,
#  12264,
#  7720,
#  12053,
#  998,
#  7080,
#  13977,
#  15068,
#  5732,
#  4196,
#  3754,
#  5487,
#  1082,
#  12106,
#  8833,
#  6186,
#  6967,
#  1894,
#  15391,
#  67,
#  13478,
#  16263,
#  6312,
#  2678,
#  10333,
#  11950,
#  12881,
#  12055,
#  401,
#  14737,
#  11895,
#  1817,
#  4191,
#  4706,
#  8800,
#  4651,
#  3164,
#  6153,
#  10213,
#  11100,
#  6926,
#  13507,
#  12101,
#  1495,
#  4565,
#  16309,
#  6254,
#  12782,
#  3625,
#  5527,
#  616,
#  11944,
#  6549,
#  4839,
#  15035,
#  2971,
#  6883,
#  3240,
#  7338,
#  5142,
#  7261,
#  1736,
#  9068,
#  3536,
#  8549,
#  9285,
#  6894,
#  7539,
#  4380,
#  8807,
#  13664,
#  14025,
#  10444,
#  6491,
#  6621,
#  10188,
#  922,
#  6007,
#  11312,
#  7036,
#  16349,
#  8239,
#  8261,
#  6229,
#  3818,
#  8949,
#  12,
#  11838,
#  7885,
#  4686,
#  4546,
#  5462,
#  12068,
#  640,
#  14470,
#  15775,
#  8072,
#  15484,
#  13964,
#  3670,
#  3697,
#  15740,
#  8219,
#  13600,
#  12422,
#  13432,
#  5740,
#  9822,
#  8412,
#  11635,
#  14541,
#  11364,
#  11314,
#  15980,
#  1089,
#  10539,
#  16011,
#  4852]

# %%
slice_psi_stem = df_rmse[(df_rmse['slope_gpp17-19'] < -0.1) &(df_rmse['slope_gpp17-19'] > -0.5)]
slice_psi_stem.sort_values(by = 'slope_gpp17-19', ascending=False)['fid'].to_list()
# Out:
# [8193,
#  454,
#  11671,
#  6521,
#  12277,
#  4576,
#  9792,
#  1387,
#  13066,
#  10347,
#  12123,
#  4217,
#  15260,
#  7585,
#  10066,
#  8354,
#  294,
#  10220,
#  14573,
#  12272,
#  6477,
#  1730,
#  7831,
#  7424,
#  5047,
#  5024,
#  15688,
#  5637,
#  7558,
#  1084,
#  10299,
#  12937,
#  8971,
#  2968,
#  9942,
#  6953,
#  9210,
#  6655,
#  10759,
#  11797,
#  8514,
#  1662,
#  3815,
#  9177,
#  11373,
#  12779,
#  14038,
#  4359,
#  14222,
#  8408,
#  6225,
#  1101,
#  5157,
#  12958,
#  10141,
#  2392,
#  1997,
#  16113,
#  13579,
#  1133,
#  13083,
#  5652,
#  5243,
#  4493,
#  11157,
#  10457,
#  10920,
#  2202,
#  6333,
#  4173,
#  7428,
#  16250,
#  9331,
#  5980,
#  14936,
#  16171,
#  12440,
#  15008,
#  14335,
#  3499,
#  69,
#  13060,
#  4508,
#  9788,
#  6851,
#  6827,
#  12201,
#  14659,
#  14243,
#  11431,
#  7287,
#  7444,
#  2867,
#  12635,
#  12308,
#  1222,
#  7394,
#  10562,
#  12908,
#  7520,
#  2707,
#  8337,
#  15823,
#  14815,
#  5298,
#  13406,
#  13861,
#  4897,
#  4536,
#  2139,
#  13751,
#  15676,
#  8547,
#  12258,
#  7126,
#  9644,
#  16367,
#  4738,
#  7064,
#  14467,
#  15529,
#  12798,
#  1252,
#  6021,
#  3641,
#  4403,
#  1816,
#  14296,
#  6126,
#  768,
#  9512,
#  4955,
#  2096,
#  5841,
#  935,
#  12343,
#  10649,
#  6313,
#  9827,
#  1839,
#  653,
#  13834,
#  12528,
#  8417,
#  3753,
#  13691,
#  8629,
#  13845,
#  6247,
#  1618,
#  9450,
#  5369,
#  5030,
#  13871,
#  9458,
#  13171,
#  11127,
#  8504,
#  3100,
#  10361,
#  7692,
#  3940,
#  2123,
#  118,
#  9756,
#  7407,
#  14080,
#  15522,
#  15180,
#  6565,
#  9971,
#  11732,
#  1472,
#  812,
#  7934,
#  1628,
#  12361,
#  16215,
#  11371,
#  9393,
#  5950,
#  9596,
#  4043,
#  15441,
#  8474,
#  10370,
#  4339,
#  6427,
#  7416,
#  1974,
#  13996,
#  4624,
#  8922,
#  10366,
#  15600,
#  14281,
#  9669,
#  3749,
#  1981,
#  6462,
#  12651,
#  1440,
#  1613,
#  7145,
#  8270,
#  5292,
#  3537,
#  9516,
#  12290,
#  7607,
#  2487,
#  2437,
#  16081,
#  809,
#  15637,
#  11381,
#  6985,
#  1201,
#  16118,
#  12003,
#  15981,
#  13619,
#  5340,
#  3231,
#  13567,
#  4074,
#  12706,
#  6481,
#  11242,
#  12951,
#  9013,
#  6498,
#  4154,
#  2402,
#  11960,
#  16131,
#  13747,
#  15725,
#  7342,
#  10695,
#  3050,
#  10638,
#  1134,
#  1288,
#  15633,
#  14942,
#  8482,
#  8868,
#  4520,
#  12056,
#  15263,
#  9685,
#  13558,
#  8560,
#  10145,
#  11266,
#  16298,
#  12589,
#  9812,
#  2643,
#  6642,
#  14616,
#  15816,
#  11601,
#  10830,
#  11103,
#  9073,
#  1597,
#  16186,
#  3078,
#  15087,
#  12889,
#  2057,
#  10521,
#  12072,
#  6440,
#  13237,
#  14762,
#  3748,
#  5588,
#  2744,
#  15667,
#  10937,
#  5728]

# %%
import xarray

# %%
QNC_ncdf_reader(OUTPUT_DIR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 QNC_ncdf_reader(OUTPUT_DIR)
#
# TypeError: QNC_ncdf_reader.__init__() missing 3 required positional arguments: 'output_cats', 'output_identifier', and 'output_time_res'
